# %%
# Python 3
# Author: Mark O
# Project:  Pizza Order.
# An automatic pizza order program


print("Welcome to Python Pizza Deliveries!")
size = input("What size pizza do you want? S, M, or L: ").title()
add_pepperoni = input("Do you want pepperoni? Y or N: ").title()
extra_cheese = input("Do you want extra cheese? Y or N: ").title()
basic_bill = 0
pepperoni_bill = 0
cheese_bill = 0
total_bill = 0

if size == "S":
    basic_bill = 15
    if add_pepperoni == "N":
        basic_bill = 15
        pepperoni_bill = 0
        if extra_cheese == "N":
            basic_bill = 15
            pepperoni_bill = 0
            cheese_bill = 0
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
        else:
            basic_bill = 15
            pepperoni_bill = 0
            cheese_bill = 1
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
    if add_pepperoni == "Y":
        basic_bill = 15
        pepperoni_bill = 2
        if extra_cheese == "N":
            basic_bill = 15
            pepperoni_bill = 2
            cheese_bill = 0
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
        else:
            basic_bill = 15
            pepperoni_bill = 2
            cheese_bill = 1
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
elif size == "M":
    basic_bill = 20
    if add_pepperoni == "N":
        basic_bill = 20
        pepperoni_bill = 0
        if extra_cheese == "N":
            basic_bill = 20
            pepperoni_bill = 0
            cheese_bill = 0
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
        else:
            basic_bill = 20
            pepperoni_bill = 0
            cheese_bill = 1
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
    if add_pepperoni == "Y":
        basic_bill = 20
        pepperoni_bill = 3
        if extra_cheese == "N":
            basic_bill = 20
            pepperoni_bill = 3
            cheese_bill = 0
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
        else:
            basic_bill = 20
            pepperoni_bill = 3
            cheese_bill = 1
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
elif size == "L":
    basic_bill = 25
    if add_pepperoni == "N":
        basic_bill = 25
        pepperoni_bill = 0
        if extra_cheese == "N":
            basic_bill = 25
            pepperoni_bill = 0
            cheese_bill = 0
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
        else:
            basic_bill = 25
            pepperoni_bill = 0
            cheese_bill = 1
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
    if add_pepperoni == "Y":
        basic_bill = 25
        pepperoni_bill = 3
        if extra_cheese == "N":
            basic_bill = 25
            pepperoni_bill = 3
            cheese_bill = 0
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
        else:
            basic_bill = 25
            pepperoni_bill = 3
            cheese_bill = 1
            total_bill = pepperoni_bill + basic_bill + cheese_bill
            print(f"Your final bill is: ${total_bill}.")
# Out:
# Welcome to Python Pizza Deliveries!
# What size pizza do you want? S, M, or L: l
# Do you want pepperoni? Y or N: y
# Do you want extra cheese? Y or N: n
# Your final bill is: $28.
